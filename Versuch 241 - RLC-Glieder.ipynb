# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
def lin_min(x,m,c):
    return m*x+c

f=np.arange(1,11,1)
phase=np.array([72,57.6,46.4,39.7,35.28,31.1,27.7,24.2,22.7,20.9])
dphase=np.array([7.2,7.2,2.2,1.4,1.8,2.2,2.5,2.9,3.2,3.6])

# %%
plt.figure(1, figsize=(10,8))
plt.errorbar(f,phase,yerr=dphase)
plt.xscale('log')
plt.plot([1,10],[45,45])

# %%
amp=np.array([2.72,1.73,1.08,0.69,0.42])
damp=np.array([0.05,0.02,0.02,0.02,0.01])
tdiff=np.array([0.27,0.27,0.27,0.26,0.26])
logdek=np.log(amp[:-1]/amp[1:])
